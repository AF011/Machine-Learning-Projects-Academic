# %%
'''Load the dataset “student.csv and display the data,
calculate mean, median and mode for the given data,
Display the summary of the numeric values,
Draw the boxplot for the grade point,
Draw the histogram for age and grade point.
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv('Student.csv')
Dataset
# Out:
#     Roll No  Age  Grade
# 0         1   23      3
# 1         2   25      8
# 2         3   17      8
# 3         4   25      5
# 4         5   18      1
# 5         6   23     10
# 6         7   20      8
# 7         8   24      6
# 8         9   20      8
# 9        10   25      2
# 10       11   17      5
# 11       12   21      2
# 12       13   18     10
# 13       14   21     10
# 14       15   24      3
# 15       16   17      5
# 16       17   18      8
# 17       18   19      2
# 18       19   18      4
# 19       20   23      3
# 20       21   23      4
# 21       22   18      8
# 22       23   25     10
# 23       24   18      8
# 24       25   25      6
# 25       26   22      9
# 26       27   22      7
# 27       28   21      9
# 28       29   24      9
# 29       30   18      9

# %%
#Dimensions of the dataset
Dataset.shape
# Out:
# (30, 3)

# %%
#Descriptive Statistics
Dataset[['Age', 'Grade']].describe()
# Out:
#              Age      Grade
# count  30.000000  30.000000
# mean   21.066667   6.333333
# std     2.887946   2.856732
# min    17.000000   1.000000
# 25%    18.000000   4.000000
# 50%    21.000000   7.500000
# 75%    23.750000   8.750000
# max    25.000000  10.000000

# %%
#Box Plot
Dataset.Grade.plot.box()
# Out:
# <Axes: >

# %%
#Histogram
Dataset[['Age', 'Grade']].hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Grade'}>]], dtype=object)

# %%
Dataset.Grade.hist(bins=5)
# Out:
# <Axes: >
