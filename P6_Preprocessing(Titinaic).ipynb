# %%
#Titanic DataSet PreProcessing
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
#Loading the Dataset
Titanic=sb.load_dataset('titanic')
Titanic.head(n=20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
#Structure of the Dataset.
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#Columns/Features of the Dataset.
Titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#Let's look how many different genders are travelled in Titanic.
Titanic['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#Let's see how many unique values are there in survived.
Titanic['survived'].unique()
# Out:
# array([0, 1])

# %%
#Let's see how many unique age people are travelled.
Titanic['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#Let's see how many classes are present in the Titanic.
Titanic['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
#Age Category of the People Travelled.
Titanic['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
#Let's see the unique values in the deck column
Titanic['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sex=Titanic['sex']
sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
age=Titanic['age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
#Let's see any null values are present in the age subset
age.isnull().sum()
# Out:
# 177

# %%
age.iloc[:15]=np.nan
# Out:
# <ipython-input-14-39239c13ee94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age.iloc[:15]=np.nan

# %%
age.isnull().sum()
# Out:
# 191

# %%
age.shape
# Out:
# (891,)

# %%
#Average Age of the Passengers
mean=age.mean()
mean
# Out:
# 29.738814285714284

# %%
#Average Age of the Mean is 30
mean=round(mean)
mean
# Out:
# 30

# %%
Titanic['age'].unique()
# Out:
# array([  nan, 55.  ,  2.  , 31.  , 35.  , 34.  , 15.  , 28.  ,  8.  ,
#        38.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  , 14.  , 27.  ,
#         3.  ,  7.  , 49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 22.  ,
#        45.  ,  4.  , 17.  , 26.  , 32.  , 16.  , 25.  ,  0.83, 30.  ,
#        33.  , 23.  , 24.  , 20.  , 46.  , 59.  , 71.  , 37.  , 47.  ,
#        14.5 , 70.5 , 32.5 , 54.  , 12.  ,  9.  , 36.5 , 51.  , 55.5 ,
#        40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 58.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        39.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#Let's Replace the age value
age.fillna(mean, inplace=True)
age.head(n=20)
# Out:
# 0     30.0
# 1     30.0
# 2     30.0
# 3     30.0
# 4     30.0
# 5     30.0
# 6     30.0
# 7     30.0
# 8     30.0
# 9     30.0
# 10    30.0
# 11    30.0
# 12    30.0
# 13    30.0
# 14    30.0
# 15    55.0
# 16     2.0
# 17    30.0
# 18    31.0
# 19    30.0
# Name: age, dtype: float64

# %%
Titanic['age'].unique()
# Out:
# array([30.  , 55.  ,  2.  , 31.  , 35.  , 34.  , 15.  , 28.  ,  8.  ,
#        38.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  , 14.  , 27.  ,
#         3.  ,  7.  , 49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 22.  ,
#        45.  ,  4.  , 17.  , 26.  , 32.  , 16.  , 25.  ,  0.83, 33.  ,
#        23.  , 24.  , 20.  , 46.  , 59.  , 71.  , 37.  , 47.  , 14.5 ,
#        70.5 , 32.5 , 54.  , 12.  ,  9.  , 36.5 , 51.  , 55.5 , 40.5 ,
#        44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 58.  , 45.5 , 20.5 ,
#        62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  , 39.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#Let's Plot a Histogram for the age column
plt.hist(age)
plt.show()

# %%
#Let's observer the Histogram for the orginal dataset's Age Column.
plt.hist(Titanic['age'])
plt.show()

# %%
#Min Value
age.min()
# Out:
# 0.42

# %%
 #Min Value Calculation
 min_val=age.mean()-(3*age.std())
 min_val
# Out:
# -8.730101908499982

# %%
#Max Value
age.max()
# Out:
# 80.0

# %%
#Maximum value Calculation.
max_val=age.mean()+(3*age.std())
max_val
# Out:
# 68.3197090914405

# %%
#Finding Outliers
outlier=age[age>max_val]
outlier.count()
# Out:
# 7

# %%
#Text Encoding
from sklearn.preprocessing import LabelEncoder #(data preprocessing)

# %%
enc=LabelEncoder()

# %%
Titanic['age'].isnull().sum()
# Out:
# 0

# %%
Titanic['age']=enc.fit_transform(Titanic['age'].astype('str'))
Titanic['age']
# Out:
# 0      33
# 1      33
# 2      33
# 3      33
# 4      33
#        ..
# 886    28
# 887    16
# 888    33
# 889    27
# 890    36
# Name: age, Length: 891, dtype: int64

# %%
Titanic.head(n=10)
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0         0       3    male   33      1      0   7.2500        S   Third
# 1         1       1  female   33      1      0  71.2833        C   First
# 2         1       3  female   33      0      0   7.9250        S   Third
# 3         1       1  female   33      1      0  53.1000        S   First
# 4         0       3    male   33      0      0   8.0500        S   Third
# 5         0       3    male   33      0      0   8.4583        Q   Third
# 6         0       1    male   33      0      0  51.8625        S   First
# 7         0       3    male   33      3      1  21.0750        S   Third
# 8         1       3  female   33      0      2  11.1333        S   Third
# 9         1       2  female   33      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# ...

# %%
Titanic['sex']=enc.fit_transform(Titanic['sex'])
Titanic['sex']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: sex, Length: 891, dtype: int64

# %%
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare embarked   class    who  \
# 0         0       3    1   33      1      0   7.2500        S   Third    man
# 1         1       1    0   33      1      0  71.2833        C   First  woman
# 2         1       3    0   33      0      0   7.9250        S   Third  woman
# 3         1       1    0   33      1      0  53.1000        S   First  woman
# 4         0       3    1   33      0      0   8.0500        S   Third    man
# 5         0       3    1   33      0      0   8.4583        Q   Third    man
# 6         0       1    1   33      0      0  51.8625        S   First    man
# 7         0       3    1   33      3      1  21.0750        S   Third  child
# 8         1       3    0   33      0      2  11.1333        S   Third  woman
# 9         1       2    0   33      1      0  30.0708        C  Second  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# ...

# %%
Titanic['embarked']=enc.fit_transform(Titanic['embarked'].astype('str'))
Titanic['embarked']
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: embarked, Length: 891, dtype: int64

# %%
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked   class    who  \
# 0         0       3    1   33      1      0   7.2500         2   Third    man
# 1         1       1    0   33      1      0  71.2833         0   First  woman
# 2         1       3    0   33      0      0   7.9250         2   Third  woman
# 3         1       1    0   33      1      0  53.1000         2   First  woman
# 4         0       3    1   33      0      0   8.0500         2   Third    man
# 5         0       3    1   33      0      0   8.4583         1   Third    man
# 6         0       1    1   33      0      0  51.8625         2   First    man
# 7         0       3    1   33      3      1  21.0750         2   Third  child
# 8         1       3    0   33      0      2  11.1333         2   Third  woman
# 9         1       2    0   33      1      0  30.0708         0  Second  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# ...

# %%
Titanic['class']=enc.fit_transform(Titanic['class'].astype('str'))
Titanic['class']
# Out:
# 0      2
# 1      0
# 2      2
# 3      0
# 4      2
#       ..
# 886    1
# 887    0
# 888    2
# 889    0
# 890    2
# Name: class, Length: 891, dtype: int64

# %%
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    1   33      1      0   7.2500         2      2    man
# 1         1       1    0   33      1      0  71.2833         0      0  woman
# 2         1       3    0   33      0      0   7.9250         2      2  woman
# 3         1       1    0   33      1      0  53.1000         2      0  woman
# 4         0       3    1   33      0      0   8.0500         2      2    man
# 5         0       3    1   33      0      0   8.4583         1      2    man
# 6         0       1    1   33      0      0  51.8625         2      0    man
# 7         0       3    1   33      3      1  21.0750         2      2  child
# 8         1       3    0   33      0      2  11.1333         2      2  woman
# 9         1       2    0   33      1      0  30.0708         0      1  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# ...

# %%
Titanic['who']=enc.fit_transform(Titanic['who'].astype('str'))
Titanic['who']
# Out:
# 0      1
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 886    1
# 887    2
# 888    2
# 889    1
# 890    1
# Name: who, Length: 891, dtype: int64

# %%
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# ...

# %%
Titanic['adult_male']=enc.fit_transform(Titanic['adult_male'].astype('str'))
Titanic['adult_male']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: adult_male, Length: 891, dtype: int64

# %%
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male deck  embark_town alive  alone
# 0           1  NaN  Southampton    no  False
# 1           0    C    Cherbourg   yes  False
# ...

# %%
deck=Titanic['deck']
deck
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
deck.isnull().sum()
# Out:
# 688

# %%
Titanic['deck'].isnull().sum()
# Out:
# 688

# %%
Titanic['deck']=enc.fit_transform(Titanic['deck'].astype('str'))
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male  deck  embark_town alive  alone
# 0           1     7  Southampton    no  False
# 1           0     2    Cherbourg   yes  False
# ...

# %%
Titanic['embark_town']=enc.fit_transform(Titanic['embark_town'].astype('str'))
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male  deck  embark_town alive  alone
# 0           1     7            2    no  False
# 1           0     2            0   yes  False
# ...

# %%
Titanic['alive']=enc.fit_transform(Titanic['alive'].astype('str'))
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     7            2      0  False
# 1           0     2            0      1  False
# ...

# %%
Titanic['alone']=enc.fit_transform(Titanic['alone'].astype('str'))
Titanic.head(10)
# Out:
#    survived  pclass  sex  age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1   33      1      0   7.2500         2      2    1
# 1         1       1    0   33      1      0  71.2833         0      0    2
# 2         1       3    0   33      0      0   7.9250         2      2    2
# 3         1       1    0   33      1      0  53.1000         2      0    2
# 4         0       3    1   33      0      0   8.0500         2      2    1
# 5         0       3    1   33      0      0   8.4583         1      2    1
# 6         0       1    1   33      0      0  51.8625         2      0    1
# 7         0       3    1   33      3      1  21.0750         2      2    0
# 8         1       3    0   33      0      2  11.1333         2      2    2
# 9         1       2    0   33      1      0  30.0708         0      1    0
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     7            2      0      0
# 1           0     2            0      1      0
# ...

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    int64
#  3   age          891 non-null    int64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    int64
#  8   class        891 non-null    int64
#  9   who          891 non-null    int64
#  10  adult_male   891 non-null    int64
#  11  deck         891 non-null    int64
#  12  embark_town  891 non-null    int64
#  13  alive        891 non-null    int64
#  14  alone        891 non-null    int64
# dtypes: float64(1), int64(14)
# memory usage: 104.5 KB

# %%
#Normalise Convert from Zero to One
Titanic_normal=(Titanic-Titanic.min())/(Titanic.max()-Titanic.min())
Titanic_normal.head(10)
# Out:
#    survived  pclass  sex      age  sibsp     parch      fare  embarked  class  \
# 0       0.0     1.0  1.0  0.37931  0.125  0.000000  0.014151  0.666667    1.0
# 1       1.0     0.0  0.0  0.37931  0.125  0.000000  0.139136  0.000000    0.0
# 2       1.0     1.0  0.0  0.37931  0.000  0.000000  0.015469  0.666667    1.0
# 3       1.0     0.0  0.0  0.37931  0.125  0.000000  0.103644  0.666667    0.0
# 4       0.0     1.0  1.0  0.37931  0.000  0.000000  0.015713  0.666667    1.0
# 5       0.0     1.0  1.0  0.37931  0.000  0.000000  0.016510  0.333333    1.0
# 6       0.0     0.0  1.0  0.37931  0.000  0.000000  0.101229  0.666667    0.0
# 7       0.0     1.0  1.0  0.37931  0.375  0.166667  0.041136  0.666667    1.0
# 8       1.0     1.0  0.0  0.37931  0.000  0.333333  0.021731  0.666667    1.0
# 9       1.0     0.5  0.0  0.37931  0.125  0.000000  0.058694  0.000000    0.5
#
#    who  adult_male      deck  embark_town  alive  alone
# ...

# %%
#Standardise the Values
Titanic_std=(Titanic-Titanic.max())/Titanic.std()
Titanic_std.head(10)
# Out:
#    survived    pclass       sex       age     sibsp     parch       fare  \
# 0 -2.055108  0.000000  0.000000 -3.164213 -6.347805 -7.443640 -10.163903
# 1  0.000000 -2.392141 -2.092094 -3.164213 -6.347805 -7.443640  -8.875336
# 2  0.000000  0.000000 -2.092094 -3.164213 -7.254634 -7.443640 -10.150320
# 3  0.000000 -2.392141 -2.092094 -3.164213 -6.347805 -7.443640  -9.241246
# 4 -2.055108  0.000000  0.000000 -3.164213 -7.254634 -7.443640 -10.147805
# 5 -2.055108  0.000000  0.000000 -3.164213 -7.254634 -7.443640 -10.139588
# 6 -2.055108 -2.392141  0.000000 -3.164213 -7.254634 -7.443640  -9.266149
# 7 -2.055108  0.000000  0.000000 -3.164213 -4.534146 -6.203034  -9.885697
# 8  0.000000  0.000000 -2.092094 -3.164213 -7.254634 -4.962427 -10.085758
# 9  0.000000 -1.196070 -2.092094 -3.164213 -6.347805 -7.443640  -9.704671
#
#    embarked     class       who  adult_male      deck  embark_town     alive  \
# 0  -1.25908  0.000000 -1.682676     0.00000  0.000000     -1.25908 -2.055108
# ...

# %%
Titanic_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    float64
#  1   pclass       891 non-null    float64
#  2   sex          891 non-null    float64
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    float64
#  5   parch        891 non-null    float64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    float64
#  8   class        891 non-null    float64
#  9   who          891 non-null    float64
#  10  adult_male   891 non-null    float64
#  11  deck         891 non-null    float64
#  12  embark_town  891 non-null    float64
#  13  alive        891 non-null    float64
#  14  alone        891 non-null    float64
# dtypes: float64(15)
# memory usage: 104.5 KB
